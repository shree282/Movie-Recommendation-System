# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
df = pd.read_csv("/content/movies.csv")
df.head()
# Out:
#                title                   genres
# 0    The Dark Knight       Action|Crime|Drama
# 1          Inception   Action|Sci-Fi|Thriller
# 2       Interstellar   Adventure|Drama|Sci-Fi
# 3         The Matrix            Action|Sci-Fi
# 4  Avengers: Endgame  Action|Adventure|Sci-Fi

# %%
df['genres'] = df['genres'].fillna('').str.replace('|', ' ', regex=False)
vectorizer = TfidfVectorizer(stop_words='english')
tfidf_matrix = vectorizer.fit_transform(df['genres'])
similarity = cosine_similarity(tfidf_matrix)
print('TF-IDF matrix shape:', tfidf_matrix.shape)
# Out:
# TF-IDF matrix shape: (30, 12)

# %%
indices = pd.Series(df.index, index=df['title']).drop_duplicates()

def recommend(title, n=5):
    idx = indices[title]
    scores = sorted(enumerate(similarity[idx]), key=lambda x: x[1], reverse=True)
    scores = [x for x in scores if x[0] != idx][:n]
    return df.iloc[[i for i, _ in scores]][['title','genres']]

recommend('Inception', 5)
# Out:
#                       title                     genres
# 3                The Matrix              Action Sci-Fi
# 7             Jurassic Park  Adventure Sci-Fi Thriller
# 4         Avengers: Endgame    Action Adventure Sci-Fi
# 5                  Iron Man    Action Adventure Sci-Fi
# 29  Spider-Man: No Way Home    Action Adventure Sci-Fi
